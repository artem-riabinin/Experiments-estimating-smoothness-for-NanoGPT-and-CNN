# %%
import numpy as np
import re
import matplotlib.pyplot as plt
from scipy.optimize import minimize

def fit_positive_linear(x, y):
    x = np.asarray(x)
    y = np.asarray(y)
    penalty_weight = 0
    
    # Loss function (mean squared error)
    def loss(params):
        a, b = params
        violation = np.maximum(0, y - (a * x + b))  # Capture violations
        penalty = penalty_weight * np.sum(violation ** 2)  # Stronger penalty for violations
        return np.sum((a * x + b - y) ** 2) + penalty
    
    # Initial guess 
    initial_guess = [1.0, 1.0]
    
    # Constraints a > 0, b > 0
    bounds = [(1e-6, None), (1e-6, None)]  # Small threshold to avoid zero
    
    # Run optimization
    result = minimize(loss, initial_guess, bounds=bounds)
    
    return result.x  # Returns [a, b]

# %%
# Sample log file path
log_file_path = "output2.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(24\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values[1:], L_estimated_values[1:])
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
mse = np.mean(np.square(np.abs(y_actual[1:] - y_predicted[1:]) / np.abs(y_actual[1:])))
x = np.arange(50, 5001, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=16)
plt.ylim(top=0.07)
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title(f'Name: module._orig_mod.transformer.h.4.attn.c_q.weight\n'
          f'Size: [768, 768] | MSE_rel: {mse:.4f}', fontsize=16)
plt.savefig('plot1_1_l2.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Optimal parameters: L_1 = 3.4288, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output2.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(25\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values[1:], L_estimated_values[1:])
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
mse = np.mean(np.square(np.abs(y_actual[1:] - y_predicted[1:]) / np.abs(y_actual[1:])))
x = np.arange(50, 5001, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=16)
plt.ylim(top=0.07)
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title(f'Name: module._orig_mod.transformer.h.4.attn.c_k.weight\n'
          f'Size: [768, 768] | MSE_rel: {mse:.4f}', fontsize=16)
plt.savefig('plot2_1_l2.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Optimal parameters: L_1 = 3.5075, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output2.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(26\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values[1:], L_estimated_values[1:])
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
mse = np.mean(np.square(np.abs(y_actual[1:] - y_predicted[1:]) / np.abs(y_actual[1:])))
x = np.arange(50, 5001, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=16)
plt.ylim(top=0.3)
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title(f'Name: module._orig_mod.transformer.h.4.attn.c_v.weight\n'
          f'Size: [768, 768] | MSE_rel: {mse:.4f}', fontsize=16)
plt.savefig('plot3_1_l2.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Optimal parameters: L_1 = 3.7457, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output2.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(27\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values[1:], L_estimated_values[1:])
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
mse = np.mean(np.square(np.abs(y_actual[1:] - y_predicted[1:]) / np.abs(y_actual[1:])))
x = np.arange(50, 5001, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=16)
plt.ylim(top=0.14)
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title(f'Name: module._orig_mod.transformer.h.4.attn.c_proj.weight\n'
          f'Size: [768, 768] | MSE_rel: {mse:.4f}', fontsize=16)
plt.savefig('plot4_1_l2.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Optimal parameters: L_1 = 3.5870, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output2.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(28\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values[1:], L_estimated_values[1:])
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
mse = np.mean(np.square(np.abs(y_actual[1:] - y_predicted[1:]) / np.abs(y_actual[1:])))
x = np.arange(50, 5001, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=16)
plt.ylim(top=0.04)
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title(f'Name: module._orig_mod.transformer.h.4.mlp.c_fc.weight\n'
          f'Size: [3072, 768] | MSE_rel: {mse:.4f}', fontsize=16)
plt.savefig('plot5_1_l2.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Optimal parameters: L_1 = 1.6840, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output2.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(29\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values[1:], L_estimated_values[1:])
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
mse = np.mean(np.square(np.abs(y_actual[1:] - y_predicted[1:]) / np.abs(y_actual[1:])))
x = np.arange(50, 5001, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=16)
plt.ylim(bottom=0.05, top=0.6)
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title(f'Name: module._orig_mod.transformer.h.4.mlp.c_proj.weight\n'
          f'Size: [768, 3072] | MSE_rel: {mse:.4f}', fontsize=16)
plt.savefig('plot6_1_l2.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Optimal parameters: L_1 = 6.6370, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output2.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(72\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values[1:], L_estimated_values[1:])
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
mse = np.mean(np.square(np.abs(y_actual[1:] - y_predicted[1:]) / np.abs(y_actual[1:])))
x = np.arange(50, 5001, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=16)
plt.grid()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title(f'Name: module._orig_mod.transformer.wte.weight\n'
          f'Size: [50304, 768] | MSE_rel: {mse:.4f}', fontsize=16)
plt.savefig('plot7_l2.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Optimal parameters: L_1 = 0.1180, L_0 = 0.0125
